# %% [markdown]
# # A2 - Code
#
# This notebook holds the code logic for group 3's Assignment 2.
# Made by:
# - Lloyd Nsambu  # 169113748
# **
# **
#
# - [**Setup**](#setup)
# - [**Problem 1(a)**](#Problem-1(a)visualization)

# %% [markdown]
# ## Setup

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
## importing the datasets

customer_df = pd.read_csv("CustomerDataset_Q1.csv")
customer_profiles_df = pd.read_csv("CustomerProfiles_Q2.csv")

# %%
## viewing what in the dfs
customer_df.info()
## may neeed ot rename columns!
customer_df.rename(columns={"c":"y"}).head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x1      20 non-null     float64
#  1   x2      20 non-null     float64
#  2   c       20 non-null     int64
# dtypes: float64(2), int64(1)
# memory usage: 612.0 bytes
#      x1   x2  y
# 0  0.50  0.5  1
# 1  0.50  0.9  1
# 2  0.75  1.9  1
# 3  0.75  2.6  1
# 4  1.20  0.6  0

# %% [markdown]
# ## Problem-1(a)visualization

# %%
# creating a 2D plot of the customer data. 

plt.title("Customer Behaviour Relationship")
plt.xlabel("Avg Amount Spent per Purchase ($ thousands)")
plt.ylabel("Frequency of Purchases a Month")
sns.scatterplot(x = customer_df["x1"], y=customer_df["x2"], color="purple", hue=customer_df["c"])
handles, _ = plt.gca().get_legend_handles_labels() 
plt.legend(handles, ["No","Yes"],loc="best", fontsize=12, title="Membership Interest")
plt.show()
